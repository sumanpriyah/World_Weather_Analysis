# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
lats= np.random.uniform(-90,90, size=2000)+random.random()
lngs=np.random.uniform(-90,90, size =2000)+ random.random()

# %%
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs )

# %%
for coordinate in coordinates:
    print (citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
        citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# khorramshahr ir
# ushuaia ar
# cayenne gf
# taolanaro mg
# garmsar ir
# kuybysheve ua
# melbu no
# bredasdorp za
# saint-philippe re
# demerval lobao br
# ushuaia ar
# cape town za
# touros br
# ust-kulom ru
# nuuk gl
# henties bay na
# torbay ca
# gao ml
# temirtau ru
# varhaug no
# san carlos del zulia ve
# gorodishche ru
# busselton au
# hermanus za
# bandarbeyla so
# mahebourg mu
# tasiilaq gl
# quatre cocos mu
# barkly west za
# alma us
# port alfred za
# mar del plata ar
# toftir fo
# san cristobal ec
# cidreira br
# belushya guba ru
# punta arenas cl
# qaanaaq gl
# gospic hr
# balkhash kz
# kargasok ru
# ushuaia ar
# port alfred za
# dikson ru
# vila velha br
# hofn is
# qaanaaq gl
# clyde river ca
# ushuaia ar
# georgetown sh
# mabaruma gy
# souillac mu
# dinsor so
# kebemer sn
# suluktu kg
# andenes no
# barranca pe
# east london za
# barentsburg sj
# muzaffarnagar in
# alta floresta br
# qaanaaq gl
# chuy uy
# puerto madryn ar
# namibe ao
# chuy uy
# narsaq gl
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Create an empty list to hold the weather data.
city_data  = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_des=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description":city_weather_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khorramshahr
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | garmsar
# Processing Record 6 of Set 1 | kuybysheve
# Processing Record 7 of Set 1 | melbu
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | demerval lobao
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | touros
# Processing Record 13 of Set 1 | ust-kulom
# Processing Record 14 of Set 1 | nuuk
# Processing Record 15 of Set 1 | henties bay
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | gao
# Processing Record 18 of Set 1 | temirtau
# Processing Record 19 of Set 1 | varhaug
# Processing Record 20 of Set 1 | san carlos del zulia
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
Weather_Database_df= pd.DataFrame(city_data)
Weather_Database_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Khorramshahr  30.4397  48.1664     51.75        27           0
# 1         Ushuaia -54.8000 -68.3000     53.26        66          75
# 2         Cayenne   4.9333 -52.3333     80.10         1          75
# 3         Garmsar  35.2182  52.3409     48.83        33           0
# 4      Kuybysheve  47.3580  36.6491     34.27        61           0
# 5           Melbu  68.5044  14.8297     30.02        69          40
# 6      Bredasdorp -34.5322  20.0403     60.64        86          40
# 7  Saint-Philippe -21.3585  55.7679     74.79        83          28
# 8  Demerval Lobao  -5.3583 -42.6764     74.61        95          98
# 9       Cape Town -33.9258  18.4232     61.27        70          92
#
#    Wind Speed Country Current Description
# 0        7.63      IR           clear sky
# 1       10.36      AR       broken clouds
# 2       10.36      GF       broken clouds
# 3       15.70      IR           clear sky
# ...

# %%
order_column= ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
Weather_Database_df=Weather_Database_df[order_column]
Weather_Database_df
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khorramshahr      IR  30.4397  48.1664     51.75        27           0
# 1           Ushuaia      AR -54.8000 -68.3000     53.26        66          75
# 2           Cayenne      GF   4.9333 -52.3333     80.10         1          75
# 3           Garmsar      IR  35.2182  52.3409     48.83        33           0
# 4        Kuybysheve      UA  47.3580  36.6491     34.27        61           0
# ..              ...     ...      ...      ...       ...       ...         ...
# 726         Koungou      YT -12.7336  45.2042     78.51        94           0
# 727           Qeshm      IR  26.9581  56.2719     69.67        72           0
# 728           Tingi      TZ -11.3000  35.0333     63.59        95          96
# 729         Ambanja      MG -13.6833  48.4500     78.73        86          26
# 730  Gornopravdinsk      RU  60.0500  69.9000     12.58        88          12
#
# ...

# %%
Weather_Database_df.to_csv(r'Weather_Database\WeatherPy_Database.csv', index_label="City_ID")
